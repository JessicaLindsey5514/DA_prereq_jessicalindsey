# %%
paintcolors = ['bluebird','lilypads','smiley face', 'after rain', 'firefly', 'noble blush', 'venom', 'florida sunset']
print(f"Here's a list of colors I am using to paint my house: {paintcolors}")

calmcolor = input("Which color sounds like a relaxing color for my bedroom?")
print(f"{calmcolor} sounds perfect!")

print("I think the list looks better like this:")

for color in paintcolors:
    print(color)
# Out:
# Here's a list of colors I am using to paint my house: ['bluebird', 'lilypads', 'smiley face', 'after rain', 'firefly', 'noble blush', 'venom', 'florida sunset']
# after rain sounds perfect!
# I think the list looks better like this:
# bluebird
# lilypads
# smiley face
# after rain
# firefly
# noble blush
# venom
# florida sunset

# %% [markdown]
# Hello! My name is Jessica and for the past 16 years I have worked as a bartender/server. I am at a point in my life where I no longer want to work in the service industry. It's been physically and mentally draining especially post-covid.
#
# I heard about this program a few years and a couple previous students told me they thought it might be something I enjoy. Which is interesting because I have zero tech knowledge. But I've enjoyed the prework and into classes, and I'm hoping that this can become a fruitful career move for me.
#
# I had trouble deciding on a pathway, I was stuck between web dev and data analysis. A lot of people consider me to be a creative person, but after talking with a couple close friends I do believe I thrive the most in an enviorment where I am solving problems and thinking strategically (no one in my partners family can beat me at scrabble!). I also enjoy learning new things and how the relate to the world we live in. I love patterns, which is why I think I did well as a server/bartender for so long.
#
# I'm both nervous and excited about this next step in the program. I am very green to tech, so i dont really know specifics on what i want to learn, but I aspire to be as spongelike in this process as humanly possible.
